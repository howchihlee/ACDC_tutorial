# %%
from ACDC.random_walk_classifier import * 
from ACDC.cell_type_annotation import *

# %%
import pandas as pd
import numpy as np
from collections import Counter

path = 'data/AML_benchmark/'
df = pd.read_csv(path + 'AML_benchmark.csv.gz', sep=',', header = 0, compression = 'gzip')

df = df.drop(['Time', 'Cell_length','file_number', 'event_number', 'DNA1(Ir191)Di',
              'DNA2(Ir193)Di', 'Viability(Pt195)Di', 'subject'], axis = 1)

channels = [item[:item.find('(')] for item in df.columns[:-1]]
df.columns = channels + ['cell_type']


df = df.loc[df['cell_type'] != 'NotDebrisSinglets']

table = pd.read_csv(path + 'AML_table.csv', sep=',', header=0, index_col=0)
table = table.fillna(0)

cts, channels = get_label(table)

X0= np.arcsinh((df[channels].values - 1.0)/5.0)

# %%
idx2ct = [key for idx, key in enumerate(table.index)]
idx2ct.append('unknown')

ct2idx = {key:idx for idx, key in enumerate(table.index)}
ct2idx['unknown'] = len(table.index)
        
ct_score = np.abs(table.as_matrix()).sum(axis = 1)

## compute manual gated label
y0 = np.zeros(df.cell_type.shape)

for i, ct in enumerate(df.cell_type):
    if ct in ct2idx:
        y0[i] = ct2idx[ct]
    else:
        y0[i] = ct2idx['unknown']

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
import phenograph
from sklearn.cross_validation import StratifiedKFold
import pickle
n_neighbor = 10
thres = 0.5
# Out:
# /home/hcl/.local/lib/python3.5/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
import time

skf = StratifiedKFold(y0, n_folds=5, shuffle=True, random_state=0)
result = []
score_final = []


process_time = []
c = 0
for tr, te in skf:
    print('%02d th batch' % c)
    if c == 1:
        break
    c += 1
    
    X = X0.copy()
    y_true = y0.copy()

    X = X[tr, :]
    y_true = y_true[tr]

    mk_model =  compute_marker_model(pd.DataFrame(X, columns = channels), table, 0.0)

    ## compute posterior probs
    tic = time.clock()
    score = get_score_mat(X, [], table, [], mk_model)
    score = np.concatenate([score, 1.0 - score.max(axis = 1)[:, np.newaxis]], axis = 1)    

    ## get indices     
    ct_index = get_unique_index(X, score, table, thres)
    
    ## baseline - classify events    
    y_pred_index = np.argmax(score, axis = 1)
    
    toc = time.clock()
    time0 = toc - tic
    
    
    
    ## running ACDC
    tic = time.clock()
    res_c = get_landmarks(X, score, ct_index, idx2ct, phenograph, thres)

    landmark_mat, landmark_label = output_feature_matrix(res_c, [idx2ct[i] for i in range(len(idx2ct))]) 

    landmark_label = np.array(landmark_label)

    lp, y_pred = rm_classify(X, landmark_mat, landmark_label, n_neighbor)

    process_time.append(toc-tic)
    
    res = phenograph.cluster(X, k=30, directed=False, prune=False, min_cluster_size=10, jaccard=True,
                        primary_metric='euclidean', n_jobs=-1, q_tol=1e-3)
    
    toc = time.clock()
    time1 = toc - tic
    
    
    ## running phenograph classification
    tic = time.clock()
    y_pred_oracle = np.zeros_like(y_true)
    for i in range(max(res[0])+1):
        ic, nc = Counter(y_true[res[0] == i]).most_common(1)[0]
        y_pred_oracle[res[0] == i] = ic
        
    score_final.append([accuracy_score(y_true, [ct2idx[c] for c in y_pred]), 
                    accuracy_score(y_true, y_pred_index), 
                    accuracy_score(y_true, y_pred_oracle)])
    
    toc = time.clock()
    time2 = toc - tic   
    
    
    result.append((y_true, y_pred, y_pred_index, y_pred_oracle))
    process_time.append((time0, time1, time2))
    
    pickle.dump(result, open('processed_file/AML/event_classidication_AML.p', 'wb'))
# Out:
# 00 th batch
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 0.06403636932373047 seconds
# Jaccard graph constructed in 0.17176246643066406 seconds
# Wrote graph to binary file in 0.026288986206054688 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.585133
# After 11 runs, maximum modularity is Q = 0.588281
# Louvain completed 31 runs in 0.45229387283325195 seconds
# PhenoGraph complete in 0.738379955291748 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 7.25830602645874 seconds
# Jaccard graph constructed in 3.6772594451904297 seconds
# Wrote graph to binary file in 0.7461972236633301 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.644861
# After 2 runs, maximum modularity is Q = 0.656376
# After 8 runs, maximum modularity is Q = 0.659961
# Louvain completed 28 runs in 13.188522577285767 seconds
# PhenoGraph complete in 25.04531693458557 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 3.2661848068237305 seconds
# Jaccard graph constructed in 1.9970760345458984 seconds
# Wrote graph to binary file in 0.3704051971435547 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.590528
# After 3 runs, maximum modularity is Q = 0.591814
# After 12 runs, maximum modularity is Q = 0.59431
# Louvain completed 32 runs in 6.932661294937134 seconds
# PhenoGraph complete in 12.652595281600952 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 0.2584860324859619 seconds
# Jaccard graph constructed in 0.6691138744354248 seconds
# Wrote graph to binary file in 0.13991427421569824 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.615206
# After 2 runs, maximum modularity is Q = 0.621502
# Louvain completed 22 runs in 1.1465167999267578 seconds
# PhenoGraph complete in 2.2399818897247314 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 0.13061833381652832 seconds
# Jaccard graph constructed in 0.44429969787597656 seconds
# Wrote graph to binary file in 0.05637335777282715 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.573516
# After 4 runs, maximum modularity is Q = 0.576682
# After 6 runs, maximum modularity is Q = 0.579549
# After 25 runs, maximum modularity is Q = 0.580892
# Louvain completed 45 runs in 1.6348261833190918 seconds
# PhenoGraph complete in 2.282259225845337 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 0.22713661193847656 seconds
# Jaccard graph constructed in 0.5576663017272949 seconds
# Wrote graph to binary file in 0.10956883430480957 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.669129
# After 3 runs, maximum modularity is Q = 0.671184
# After 8 runs, maximum modularity is Q = 0.672808
# Louvain completed 28 runs in 1.204826831817627 seconds
# PhenoGraph complete in 2.119140863418579 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 0.01806163787841797 seconds
# Jaccard graph constructed in 0.15877628326416016 seconds
# Wrote graph to binary file in 0.015852689743041992 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.669842
# After 5 runs, maximum modularity is Q = 0.671119
# After 21 runs, maximum modularity is Q = 0.673
# Louvain completed 41 runs in 0.576289176940918 seconds
# PhenoGraph complete in 0.7753379344940186 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 0.01214599609375 seconds
# Jaccard graph constructed in 0.11385965347290039 seconds
# Wrote graph to binary file in 0.01335000991821289 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.490133
# After 2 runs, maximum modularity is Q = 0.499508
# Louvain completed 22 runs in 0.29396605491638184 seconds
# PhenoGraph complete in 0.43979740142822266 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 3.6580238342285156 seconds
# Jaccard graph constructed in 2.318161725997925 seconds
# Wrote graph to binary file in 0.41722965240478516 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.635833
# After 2 runs, maximum modularity is Q = 0.650345
# Louvain completed 22 runs in 5.783289670944214 seconds
# PhenoGraph complete in 12.27575945854187 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 0.006424665451049805 seconds
# Jaccard graph constructed in 0.07183027267456055 seconds
# Wrote graph to binary file in 0.008504390716552734 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.588473
# After 3 runs, maximum modularity is Q = 0.589621
# After 4 runs, maximum modularity is Q = 0.592625
# Louvain completed 24 runs in 0.29598236083984375 seconds
# PhenoGraph complete in 0.3873143196105957 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 1.2813403606414795 seconds
# Jaccard graph constructed in 1.5956432819366455 seconds
# Wrote graph to binary file in 0.30178284645080566 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.706259
# After 3 runs, maximum modularity is Q = 0.710742
# Louvain completed 23 runs in 3.220158576965332 seconds
# PhenoGraph complete in 6.459785223007202 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 0.008994579315185547 seconds
# Jaccard graph constructed in 0.10302734375 seconds
# Wrote graph to binary file in 0.011987924575805664 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.517301
# After 2 runs, maximum modularity is Q = 0.526764
# Louvain completed 22 runs in 0.29295849800109863 seconds
# PhenoGraph complete in 0.4223062992095947 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 6.953043222427368 seconds
# Jaccard graph constructed in 3.132782220840454 seconds
# Wrote graph to binary file in 0.5927228927612305 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.670897
# After 10 runs, maximum modularity is Q = 0.672041
# After 13 runs, maximum modularity is Q = 0.673873
# Louvain completed 33 runs in 11.649834632873535 seconds
# PhenoGraph complete in 22.471691370010376 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 0.06211066246032715 seconds
# Jaccard graph constructed in 0.28675007820129395 seconds
# Wrote graph to binary file in 0.06964802742004395 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.631942
# After 2 runs, maximum modularity is Q = 0.640103
# After 11 runs, maximum modularity is Q = 0.641785
# Louvain completed 31 runs in 0.766913652420044 seconds
# PhenoGraph complete in 1.1971817016601562 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 10.871602296829224 seconds
# Jaccard graph constructed in 5.310348987579346 seconds
# Wrote graph to binary file in 1.0198094844818115 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.849872
# Louvain completed 21 runs in 14.542803287506104 seconds
# PhenoGraph complete in 31.98686122894287 seconds
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 52.07979226112366 seconds
# Jaccard graph constructed in 6.763575792312622 seconds
# Wrote graph to binary file in 4.553732633590698 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.872772
# Louvain completed 21 runs in 89.96116805076599 seconds
# PhenoGraph complete in 154.43299436569214 seconds
# 01 th batch

# %%
np.mean(score_final, axis = 0) # score of ACDC, score-based classification, phenograph classification
# Out:
# array([ 0.98308196,  0.68153294,  0.95074571])
